# %% [markdown]
# # Ciencia de Datos (Taylor´s version)
# Conjunto de datos: https://www.kaggle.com/datasets/jarredpriester/taylor-swift-spotify-dataset
#
#
# # Se importan librerias

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Base de Datos

# %%
data = pd.read_csv('taylor_swift_spotify.csv') 
data
# Out:
#       Unnamed: 0                                               name  \
# 0              0                                      Lavender Haze
# 1              1                                             Maroon
# 2              2                                          Anti-Hero
# 3              3             Snow On The Beach (feat. Lana Del Rey)
# 4              4                            You're On Your Own, Kid
# ...          ...                                                ...
# 1260        1260  Mary's Song (Oh My My My) - Instrumental w/ BG...
# 1261        1261               Our Song - Instrumental w/ BG vocals
# 1262        1262  I'm Only Me When I'm With You - Instrumental w...
# 1263        1263              Invisible - Instrumental w/ BG vocals
# 1264        1264  A Perfectly Good Heart - Instrumental w/ BG vo...
#
#                         album release_date  track_number  \
# 0     Midnights (3am Edition)   2022-10-22             1
# ...

# %% [markdown]
# Se visualizan las columnas para verificar la informacion que se utilizó, de esta manera se decidió eliminar la columna "Unnamed: 0"

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'name', 'album', 'release_date', 'track_number', 'id',
#        'uri', 'acousticness', 'danceability', 'energy', 'instrumentalness',
#        'liveness', 'loudness', 'speechiness', 'tempo', 'valence', 'popularity',
#        'duration_ms'],
#       dtype='object')

# %%
tay_data = data.drop(columns=['Unnamed: 0'])
tay_data
# Out:
#                                                    name  \
# 0                                         Lavender Haze
# 1                                                Maroon
# 2                                             Anti-Hero
# 3                Snow On The Beach (feat. Lana Del Rey)
# 4                               You're On Your Own, Kid
# ...                                                 ...
# 1260  Mary's Song (Oh My My My) - Instrumental w/ BG...
# 1261               Our Song - Instrumental w/ BG vocals
# 1262  I'm Only Me When I'm With You - Instrumental w...
# 1263              Invisible - Instrumental w/ BG vocals
# 1264  A Perfectly Good Heart - Instrumental w/ BG vo...
#
#                         album release_date  track_number  \
# 0     Midnights (3am Edition)   2022-10-22             1
# 1     Midnights (3am Edition)   2022-10-22             2
# 2     Midnights (3am Edition)   2022-10-22             3
# 3     Midnights (3am Edition)   2022-10-22             4
# ...

# %% [markdown]
# La columna "duration_ms", como su nombre lo indica, muestra la duración de las canciones en milisegundos por lo que se claculan los datos de la columna en segundo y minutos.

# %%
tay_data['duration_ms']
# Out:
# 0       202395
# 1       218270
# 2       200690
# 3       256124
# 4       194206
#          ...
# 1260    216226
# 1261    204306
# 1262    223386
# 1263    206480
# 1264    227920
# Name: duration_ms, Length: 1265, dtype: int64

# %%
tay_data['duration_ms'].dtypes
# Out:
# dtype('int64')

# %%
tay_data['duration_ms']/1000
# Out:
# 0       202.395
# 1       218.270
# 2       200.690
# 3       256.124
# 4       194.206
#          ...
# 1260    216.226
# 1261    204.306
# 1262    223.386
# 1263    206.480
# 1264    227.920
# Name: duration_ms, Length: 1265, dtype: float64

# %%
tay_data['duration_s'] = tay_data['duration_ms']/1000
tay_data['duration_m'] = tay_data['duration_s']/60
tay_data
# Out:
#                                                    name  \
# 0                                         Lavender Haze
# 1                                                Maroon
# 2                                             Anti-Hero
# 3                Snow On The Beach (feat. Lana Del Rey)
# 4                               You're On Your Own, Kid
# ...                                                 ...
# 1260  Mary's Song (Oh My My My) - Instrumental w/ BG...
# 1261               Our Song - Instrumental w/ BG vocals
# 1262  I'm Only Me When I'm With You - Instrumental w...
# 1263              Invisible - Instrumental w/ BG vocals
# 1264  A Perfectly Good Heart - Instrumental w/ BG vo...
#
#                         album release_date  track_number  \
# 0     Midnights (3am Edition)   2022-10-22             1
# 1     Midnights (3am Edition)   2022-10-22             2
# 2     Midnights (3am Edition)   2022-10-22             3
# 3     Midnights (3am Edition)   2022-10-22             4
# ...

# %%
tay_data.dtypes
# Out:
# name                 object
# album                object
# release_date         object
# track_number          int64
# id                   object
# uri                  object
# acousticness        float64
# danceability        float64
# energy              float64
# instrumentalness    float64
# liveness            float64
# loudness            float64
# speechiness         float64
# tempo               float64
# valence             float64
# popularity            int64
# duration_ms           int64
# duration_s          float64
# duration_m          float64
# dtype: object

# %% [markdown]
# Se realiza el cambio del tipo de dato para las siguentes columnas:

# %%
tay_data['release_date'] = pd.to_datetime(tay_data['release_date'])
tay_data['name']=tay_data['name'].astype('string')
tay_data['album']=tay_data['album'].astype('string')

# %%
tay_data.dtypes
# Out:
# name                        string
# album                       string
# release_date        datetime64[ns]
# track_number                 int64
# id                          object
# uri                         object
# acousticness               float64
# danceability               float64
# energy                     float64
# instrumentalness           float64
# liveness                   float64
# loudness                   float64
# speechiness                float64
# tempo                      float64
# valence                    float64
# popularity                   int64
# duration_ms                  int64
# duration_s                 float64
# duration_m                 float64
# dtype: object

# %% [markdown]
# Para esta ultima parte de la limpieza de datos, se decidio cambiar el nombre de las columnas y eliminar las columnas que no se van a necesitar para el analisis

# %%
tay_data_rename_object = {
    'name' : 'Nombre',
    'album': 'Album', 
    'release_date': 'Fecha de lanzamineto',  
    'track_number': 'Numero de pista', 
    'acousticness':'Acustica', 
    'danceability':'Bailabilida', 
    'energy':'Energía', 
    'instrumentalness':'Instrumentalidad',     
    'liveness': 'En Vivo', 
    'loudness':'Sonoridad', 
    'speechiness': 'Letra', 
    'tempo': 'Tempo', 
    'valence':'Valencia', 
    'popularity': 'Popularidad',
    'duration_m': 'Duracion (min)'}
tay_data.rename(columns=tay_data_rename_object, inplace=True, errors='raise')

# %%
tay_data.columns
# Out:
# Index(['Nombre', 'Album', 'Fecha de lanzamineto', 'Numero de pista', 'id',
#        'uri', 'Acustica', 'Bailabilida', 'Energía', 'Instrumentalidad',
#        'En Vivo', 'Sonoridad', 'Letra', 'Tempo', 'Valencia', 'Popularidad',
#        'duration_ms', 'duration_s', 'Duracion (min)'],
#       dtype='object')

# %%
new_tay_data = tay_data.drop(columns=['id','uri','duration_ms','duration_s']) #Se eliminan las columnas
new_tay_data
# Out:
#                                                  Nombre  \
# 0                                         Lavender Haze
# 1                                                Maroon
# 2                                             Anti-Hero
# 3                Snow On The Beach (feat. Lana Del Rey)
# 4                               You're On Your Own, Kid
# ...                                                 ...
# 1260  Mary's Song (Oh My My My) - Instrumental w/ BG...
# 1261               Our Song - Instrumental w/ BG vocals
# 1262  I'm Only Me When I'm With You - Instrumental w...
# 1263              Invisible - Instrumental w/ BG vocals
# 1264  A Perfectly Good Heart - Instrumental w/ BG vo...
#
#                         Album Fecha de lanzamineto  Numero de pista  Acustica  \
# 0     Midnights (3am Edition)           2022-10-22                1  0.204000
# 1     Midnights (3am Edition)           2022-10-22                2  0.059300
# ...

# %%
new_tay_data.dtypes
# Out:
# Nombre                          string
# Album                           string
# Fecha de lanzamineto    datetime64[ns]
# Numero de pista                  int64
# Acustica                       float64
# Bailabilida                    float64
# Energía                        float64
# Instrumentalidad               float64
# En Vivo                        float64
# Sonoridad                      float64
# Letra                          float64
# Tempo                          float64
# Valencia                       float64
# Popularidad                      int64
# Duracion (min)                 float64
# dtype: object

# %% [markdown]
# Se guarda el dataset

# %%
new_tay_data.to_csv('ts_data.csv', index=False)

# %% [markdown]
# Se realizó un pequeño DataFrame donde de incluya la descripcion de cada columna del DataSet original

# %%
tay_descrip = {
    'Nombre':['nombre de la canción'],
    'Album':['nombre del album'], 
    'Fecha de lanzamineto':['fecha en la que salio'],  
    'Numero de pista':['numero de cancion en el album'], 
    'Acustica':['una medida de confianza de 0,0 a 1,0 de si la pista es acústica. 1.0 representa una alta confianza en que la pista es acústica'], 
    'Bailabilida':['valor de 0,0 es menos bailable y 1,0 es más bailable.'], 
    'Energía':['medida de 0,0 a 1,0 y representa una medida perceptible de intensidad y actividad'], 
    'Instrumentalidad':['predice si una pista no contiene voces, cuanto más cerca esté el valorde 1,0, mayor será la probabilidad de que la pista no contenga contenido vocal, mientra que valores superiores a 0,5 pretenden representar pistas instrumentales'],     
    'En Vivo':['representan una mayor probabilidad de que la pista se interprete en vivo'], 
    'Sonoridad':['la sonoridad general de una pista en decibelios (dB)'], 
    'Letra':['detecta la presencia de palabras habladas en una pista,valores entre 0,33 y 0,66 describen pistas que pueden contener tanto música como voz'], 
    'Tempo':['el tempo general estimado de una pista en pulsaciones por minuto (BPM)'], 
    'Valencia':['Una medida de 0.0 a 1.0 que describe la positividad musical transmitida por una pista'], 
    'Popularida':['la popularidad de la canción de 0 a 100'],
    'Duracion (min)':['duración de la canción en minutos']
}

# %%
tay_descrip
# Out:
# {'Nombre': ['nombre de la canción'],
#  'Album': ['nombre del album'],
#  'Fecha de lanzamineto': ['fecha en la que salio'],
#  'Numero de pista': ['numero de cancion en el album'],
#  'Acustica': ['una medida de confianza de 0,0 a 1,0 de si la pista es acústica. 1.0 representa una alta confianza en que la pista es acústica'],
#  'Bailabilida': ['valor de 0,0 es menos bailable y 1,0 es más bailable.'],
#  'Energía': ['medida de 0,0 a 1,0 y representa una medida perceptible de intensidad y actividad'],
#  'Instrumentalidad': ['predice si una pista no contiene voces, cuanto más cerca esté el valorde 1,0, mayor será la probabilidad de que la pista no contenga contenido vocal, mientra que valores superiores a 0,5 pretenden representar pistas instrumentales'],
#  'En Vivo': ['representan una mayor probabilidad de que la pista se interprete en vivo'],
#  'Sonoridad': ['la sonoridad general de una pista en decibelios (dB)'],
# ...

# %%
descrip_data =pd.DataFrame(tay_descrip)

# %%
descrip_data
# Out:
#                  Nombre             Album   Fecha de lanzamineto  \
# 0  nombre de la canción  nombre del album  fecha en la que salio
#
#                  Numero de pista  \
# 0  numero de cancion en el album
#
#                                             Acustica  \
# 0  una medida de confianza de 0,0 a 1,0 de si la ...
#
#                                          Bailabilida  \
# 0  valor de 0,0 es menos bailable y 1,0 es más ba...
#
#                                              Energía  \
# 0  medida de 0,0 a 1,0 y representa una medida pe...
#
#                                     Instrumentalidad  \
# 0  predice si una pista no contiene voces, cuanto...
#
#                                              En Vivo  \
# 0  representan una mayor probabilidad de que la p...
#
#                                            Sonoridad  \
# 0  la sonoridad general de una pista en decibelio...
#
#                                                Letra  \
# ...

# %% [markdown]
# Y del mismo modo tambien se guarda este DataSet como archivo csv

# %%
descrip_data.to_csv('descrip_data.csv', index=False)
